# %%
data = pd.read_csv('Final_Merged_Data.csv')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Lasso, Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFECV

# Load the data
data = pd.read_csv('Final_Merged_Data.csv')

# Handle missing values
data = data.dropna()

# Convert 'timestamp_sentinel2' to datetime
data['timestamp_sentinel2'] = pd.to_datetime(data['timestamp_sentinel2'])

# Define the target variable (y)
target = 'Turbidity_Buoy_(NTU)'

# Select features
features = [
    'B2_AVG', 'B3_AVG', 'B4_AVG', 'B8_AVG', 'B8A_AVG', 'B11_AVG', 'B12_AVG',
    'cs_AVG', 'cs_cdf_AVG',
    'Ground_Measurements_time_diff_(seconds)', 'Lake_Height_(m)', 
    'PercentFull_Active_Lake_Storage_(%)', 'Snow_Volume_Opuha_Catchment_(mm)',
    'WDir(Deg)', 'WSpd(m/s)', 'GustDir(Deg)', 'GustSpd(m/s)', 'WindRun(Km)', 
    'Rain(mm)', 'Tdry(C)', 'TWet(C)', 'RH(%)', 'Tmax(C)', 'Tmin(C)', 
    'Pmsl(hPa)', 'Pstn(hPa)', 'Water_Temp_Buoy_(degC)', 'Water_Temp_Platform_(degC)'
]

X = data[features]
y = data[target]

# Normalise the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=features)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Define hyperparameter grid for Lasso with increased iterations
lasso_params = {'alpha': [0.01, 0.1, 1, 10, 100], 'max_iter': [1000, 5000, 10000]}

# Define hyperparameter grid for Ridge with increased iterations
ridge_params = {'alpha': [0.01, 0.1, 1, 10, 100], 'max_iter': [1000, 5000, 10000]}

# Perform GridSearchCV for Lasso
lasso = Lasso()
lasso_cv = GridSearchCV(lasso, lasso_params, cv=5)
lasso_cv.fit(X_train, y_train)

# Perform GridSearchCV for Ridge
ridge = Ridge()
ridge_cv = GridSearchCV(ridge, ridge_params, cv=5)
ridge_cv.fit(X_train, y_train)

# Get the best models
best_lasso = lasso_cv.best_estimator_
best_ridge = ridge_cv.best_estimator_

# Feature selection using RFE with cross-validation
selector = RFECV(best_lasso, step=1, cv=5)
selector = selector.fit(X_train, y_train)

# Select the most important features
selected_features = X_train.columns[selector.support_]

# Train the Lasso model with selected features
X_train_selected = selector.transform(X_train)
X_test_selected = selector.transform(X_test)
best_lasso.fit(X_train_selected, y_train)

# Make predictions with the best Lasso model
y_pred_lasso = best_lasso.predict(X_test_selected)

# Evaluate the best Lasso model
mse_lasso = mean_squared_error(y_test, y_pred_lasso)
r2_lasso = r2_score(y_test, y_pred_lasso)

# Train the Ridge model with selected features
best_ridge.fit(X_train_selected, y_train)

# Make predictions with the best Ridge model
y_pred_ridge = best_ridge.predict(X_test_selected)

# Evaluate the best Ridge model
mse_ridge = mean_squared_error(y_test, y_pred_ridge)
r2_ridge = r2_score(y_test, y_pred_ridge)

print(f"Best Lasso Regression Mean Squared Error: {mse_lasso}")
print(f"Best Lasso Regression R-squared: {r2_lasso}")

print(f"Best Ridge Regression Mean Squared Error: {mse_ridge}")
print(f"Best Ridge Regression R-squared: {r2_ridge}")

print("Selected features:", selected_features)
# Out:
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.002e+04, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.545e+04, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.550e+04, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.660e+04, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.095e+04, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.798e+03, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.148e+03, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.275e+04, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.689e+04, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.923e+03, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.717e+01, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.954e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.284e+02, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.517e+01, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.531e+02, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.492e+02, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.920e+02, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.557e+02, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.211e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.918e+02, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.531e+02, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.743e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.743e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.744e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.663e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.294e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.155e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.113e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.093e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.759e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.767e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.728e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.615e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.650e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.952e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.735e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.648e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.635e+01, tolerance: 3.390e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.492e+02, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.607e+02, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.102e+02, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.102e+02, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.075e+02, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.073e+02, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.018e+02, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.018e+02, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.019e+02, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.107e+01, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.014e+01, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.881e+01, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.802e+01, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.123e+01, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.994e+01, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.857e+01, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.685e+01, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.309e+01, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.474e+01, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.029e+01, tolerance: 2.360e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.920e+02, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.350e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.349e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.350e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.366e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.366e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.321e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.317e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.247e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.762e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.653e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.429e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.204e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.725e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.113e+01, tolerance: 3.507e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.557e+02, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.543e+02, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.004e+01, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.078e+02, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.078e+02, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.080e+02, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.068e+02, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.068e+02, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.019e+02, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.029e+02, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.015e+02, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.674e+01, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.489e+01, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.956e+01, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.832e+01, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.687e+01, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.616e+01, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.647e+01, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.110e+01, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.590e+01, tolerance: 3.686e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.211e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.216e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.216e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.174e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.149e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.142e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.140e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.140e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.156e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.139e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.174e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.237e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.281e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.511e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.514e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.490e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.335e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.280e+02, tolerance: 2.359e+01
#   model = cd_fast.enet_coordinate_descent(
# Best Lasso Regression Mean Squared Error: 168.10916875327496
# Best Lasso Regression R-squared: 0.4129457084280207
# Best Ridge Regression Mean Squared Error: 180.71138750739513
# Best Ridge Regression R-squared: 0.36893748057345876
# Selected features: Index(['B2_AVG', 'B4_AVG', 'B8A_AVG', 'cs_cdf_AVG', 'Lake_Height_(m)',
#        'PercentFull_Active_Lake_Storage_(%)', 'Water_Temp_Buoy_(degC)',
#        'Water_Temp_Platform_(degC)'],
#       dtype='object')
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.918e+02, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.746e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.401e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.401e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.295e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.284e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.284e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.285e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.249e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.063e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.622e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.598e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.254e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.884e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.823e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.731e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.657e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.724e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.823e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Program Files\Anaconda3\envs\ee\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.178e+01, tolerance: 3.827e+01
#   model = cd_fast.enet_coordinate_descent(
